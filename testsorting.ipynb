# %% [markdown]
# <a href="https://colab.research.google.com/github/monicasanchezcuberes-rgb/VIU_AlgoritmosOptimizacion_25/blob/main/testsorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install sorting
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for sorting: filename=sorting-1.0.3-py3-none-any.whl size=5859 sha256=5f71a877f9076763162382ecf9b4f7164bc036e42a525ce7a70d28979a948182
#   Stored in directory: /root/.cache/pip/wheels/1e/4f/b2/859fb60c464ab3d3d9526a5ec0f3d3166f5b9a1c719dee88ad
# Successfully built sorting
# ...

# %%
import sorting
lista = [2,1,4,7,2,3]
lista_ordenada = sorting.bubble(lista)
print(lista_ordenada)
# Out:
# [1, 2, 2, 3, 4, 7]

# %%
import os
from google.colab import userdata

token = userdata.get('github_token')
os.environ['github_token'] = token

# Configura git
# !git config --global user.email "monicasanchezcuberes@gmail.com"
# !git config --global user.name "monicasanchezcuberes-rgb"

# Clona el repo (amb token)
# !git clone https://{token}@github.com/monicasanchezcuberes-rgb/VIU_AlgoritmosOptimizacion_25.git

# Copia el fitxer
# !cp fitxer.csv nom-repo/

# Pujar canvis
# %cd nom-repo
# !git add .
# !git commit -m "Afegit fitxer des de Colab"
# !git push
# Out:
# ...
# /tmp/ipython-input-1751027619.py:12: DeprecationWarning: Argument login_or_token is deprecated, please use auth=github.Auth.Token(...) instead
#   g = Github(token)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-1751027619.py in <cell line: 0>()
#      14 repo = g.get_user().get_repo("VIU_AlgoritmosOptimizacion_25")
#      15
# ---> 16 with open("fitxer.csv", "r") as f:
#      17     content = f.read()
#      18
#
# FileNotFoundError: [Errno 2] No such file or directory: 'fitxer.csv'
